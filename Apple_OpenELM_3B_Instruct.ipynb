# %% [markdown]
# <a href="https://colab.research.google.com/github/ENKI0311/Apple_OpenELM_3B_Instruct/blob/main/Apple_OpenELM_3B_Instruct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apple OpenELM 3B Instruct
#
# ## By: John Chilton
#
# ![DALL·E 2024-05-10 18.55.13 - An imaginative representation of Apple's new large language model (LLM), embodying the vast expanse of the digital world. The image features a futuris.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Install the Libraries

# %%
# !pip install transformers

# %%
# !pip install huggingface_hub

# %% [markdown]
# # Load the Libraries

# %%
# Importing library for data manipulation
import pandas as pd

# Function to download the model from the Hugging Face model hub
from huggingface_hub import hf_hub_download

# Importing the json module
import json

# Import pandas
import pandas as pd

# Import numpy
import numpy as np

#Import os
import os

# %% [markdown]
# # Load the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Create the Model Apple OpenELM 3B Instruct

# %%
model_name_or_path = "apple/OpenELM-3B-Instruct"
model_basename = "apple/OpenELM-3B-Instruct"

# %% [markdown]
# # Load the Toeknizer meta-llama/Llama-2-7b-hf

# %%
import torch
import time
from transformers import AutoTokenizer, AutoModelForCausalLM

# Define function that prompts the model
def prompt_model(prompt, model_name, hf_access_token, max_length=1024, device=None):

    # Set device on which you'll run the model
    if not device:
        device = "cuda:0" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    # Load model and tokenizer
    tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", token=hf_access_token, trust_remote_code=True)
    model = AutoModelForCausalLM.from_pretrained(model_name, token=hf_access_token, trust_remote_code=True)
    model.to(device).eval()

    # Encode prompt
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512).to(device)

    # Generate and time the process
    start_time = time.time()
    outputs = model.generate(inputs["input_ids"], max_length=max_length)
    generation_time = time.time() - start_time

    # Decode and print output
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Generated in {generation_time:.2f} seconds: {generated_text}")

# %% [markdown]
# # Write a Recipe

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "How to make spaghetti"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Generated in 44.86 seconds: How to make spaghetti carbonara
# Spaghetti carbonara is a classic Italian pasta dish made with bacon, egg yolks, pecorino cheese, and black pepper. It's creamy, salty, and rich, making it the perfect comfort food. Here's how to make spaghetti carbonara at home!
# Ingredients
# - Spaghetti:
# - 1 lb spaghetti
# - 1/4 cup olive oil
# - 6 slices thick-cut bacon, chopped
# - 4 garlic cloves, minced
# - 1/2 cup grated pecorino cheese
# - 4 large eggs
# - 1/4 cup freshly grated Parmesan cheese
# - Salt and freshly ground black pepper, to taste
# - Optional: freshly grated nutmeg
# - Optional: freshly chopped Italian parsley
# Steps to Make It
# Gather the ingredients.
# The Spruce
# Cook the spaghetti according to package directions. Drain, reserving 1/2 cup of the pasta water.
# The Spruce
# ...

# %% [markdown]
# # Write a poem

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "write a poem about the moon"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generated in 43.80 seconds: write a poem about the moon.
#
# The moon, oh moon,
#
# Your beauty is undeniable.
#
# Your light, oh light,
#
# Shines brighter than the sun.
#
# Your mysterious ways, oh mysterious ways,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Are ever changing, yet always the same.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# ...

# %% [markdown]
# # History Question

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "who was the first president of the united states"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Generated in 43.76 seconds: who was the first president of the united states to be born outside the american colonies?
# George Washington
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# ...

# %% [markdown]
# # Tell a Joke

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "tell a funny joke"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ...

# %% [markdown]
# # Addressing the Warnings

# %%
import torch
import time
from transformers import AutoTokenizer, AutoModelForCausalLM

# Define function that prompts the model
def prompt_model(prompt, model_name, hf_access_token, max_length=1024, device=None):

    # Set device on which you'll run the model
    if not device:
        device = "cuda:0" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    # Load model and tokenizer with left padding
    tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", token=hf_access_token, trust_remote_code=True, padding_side='left')
    model = AutoModelForCausalLM.from_pretrained(model_name, token=hf_access_token, trust_remote_code=True)
    model.to(device).eval()

    # Set pad token if not already set
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    # Encode prompt with attention_mask
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512).to(device)


    # Generate and time the process
    start_time = time.time()
    outputs = model.generate(inputs["input_ids"], max_length=max_length, pad_token_id=tokenizer.pad_token_id, attention_mask=inputs["attention_mask"])
    generation_time = time.time() - start_time

    # Decode and print output
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Generated in {generation_time:.2f} seconds: {generated_text}")

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "How to make spaghetti"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Generated in 44.86 seconds: How to make spaghetti carbonara
# Spaghetti carbonara is a classic Italian pasta dish made with bacon, egg yolks, pecorino cheese, and black pepper. It's creamy, salty, and rich, making it the perfect comfort food. Here's how to make spaghetti carbonara at home!
# Ingredients
# - Spaghetti:
# - 1 lb spaghetti
# - 1/4 cup olive oil
# - 6 slices thick-cut bacon, chopped
# - 4 garlic cloves, minced
# - 1/2 cup grated pecorino cheese
# - 4 large eggs
# - 1/4 cup freshly grated Parmesan cheese
# - Salt and freshly ground black pepper, to taste
# - Optional: freshly grated nutmeg
# - Optional: freshly chopped Italian parsley
# Steps to Make It
# Gather the ingredients.
# The Spruce
# Cook the spaghetti according to package directions. Drain, reserving 1/2 cup of the pasta water.
# The Spruce
# ...

# %% [markdown]
# # Write a Poem Take_2

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "write a poem about the moon"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Generated in 44.66 seconds: write a poem about the moon.
#
# The moon, oh moon,
#
# Your beauty is undeniable.
#
# Your light, oh light,
#
# Shines brighter than the sun.
#
# Your mysterious ways, oh mysterious ways,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Are ever changing, yet always the same.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# Keep us guessing, yet always wanting more.
#
# Your phases, oh phases,
#
# ...

# %% [markdown]
# # History Question Take_2

# %%
import torch
import time
from transformers import AutoTokenizer, AutoModelForCausalLM

# Define function that prompts the model
def prompt_model(prompt, model_name, hf_access_token, max_length=1024, device=None):

    # Set device on which you'll run the model
    if not device:
        device = "cuda:0" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    # Load model and tokenizer with left padding
    tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", token=hf_access_token, trust_remote_code=True, padding_side='left')
    model = AutoModelForCausalLM.from_pretrained(model_name, token=hf_access_token, trust_remote_code=True)
    model.to(device).eval()

    # Set pad token if not already set
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    # Encode prompt with attention_mask
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1024).to(device)


    # Generate and time the process
    start_time = time.time()
    outputs = model.generate(inputs["input_ids"], max_length=max_length, pad_token_id=tokenizer.pad_token_id, attention_mask=inputs["attention_mask"])
    generation_time = time.time() - start_time

    # Decode and print output
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Generated in {generation_time:.2f} seconds: {generated_text}")

    # Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "who was the first president of the united states"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Generated in 44.45 seconds: who was the first president of the united states to be born outside the american colonies?
# George Washington
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# George Washington was born in Virginia, the first president born outside the American colonies.
# ...

# %% [markdown]
# # Tell a Joke Take_2

# %%
# Set Model version to the biggest Apple Model
model_name = "apple/OpenELM-3B-Instruct"
# Give your Hugging Face Token
hf_access_token = ""
# Define Prompt
prompt = "tell a funny joke"
# Prompt the model
prompt_model(prompt, model_name, hf_access_token)
# Out:
# Using device: cuda:0
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Adding additional parameters to test

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM, set_seed

# Set the seed for reproducibility
set_seed(42)

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", use_auth_token="")
model = AutoModelForCausalLM.from_pretrained("apple/OpenELM-3B-Instruct", use_auth_token="")

# Create the text generation pipeline
generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Define the prompt
prompt = "Once upon a time there was"

# Generate text with specific parameters, enabling sampling and specifying truncation
generated_text = generator(
    prompt,
    max_length=1024,  # Maximum length of the generated sequences
    truncation=True,  # Ensure inputs longer than `max_length` are truncated as needed
    do_sample=True,  # Enable sample-based generation to use temperature and top_p effectively
    temperature=0.01,  # Very low temperature, making the output almost deterministic
    top_p=0.95,  # Using nucleus sampling to limit the token pool
    top_k=50,  # Limiting the number of highest probability vocabulary tokens considered for generation
    num_return_sequences=1
)

print(generated_text[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:757: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:468: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# The repository for apple/OpenELM-3B-Instruct contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/apple/OpenELM-3B-Instruct.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] yes
# ...

# %% [markdown]
# the generation is encountering an issue, potentially due to how repetition_penalty or other sampling parameters are set, resulting in repeated characters which is highly unusual. Here are some steps to troubleshoot and potentially fix the issue:
#
# Adjust repetition_penalty: It seems like the repetition penalty might be set too high, or the interaction between repetition_penalty, temperature, and top_p might be causing unexpected behavior. Experiment with lowering repetition_penalty or adjusting other parameters to see if it resolves the repetition.
#
# Revisit Sampling Parameters: If the temperature is set very low (e.g., 0.01), it could be making the output almost deterministic, reducing the variability significantly. A higher temperature might introduce more randomness and prevent such repetitions.
#
# Update Parameters Usage: Ensure that you are using all parameters correctly, and that they are suitable for the type of model and task.
#
# Custom Code Execution: Since the repository requires custom code to be executed (trust_remote_code=True), make sure this code is running correctly and is compatible with the parameters you're setting. Custom code can sometimes alter model behavior in unexpected ways.

# %% [markdown]
# # Going Down the Rabbit Hole Deeper

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM, set_seed

# Set the seed for reproducibility
set_seed(42)

# Load tokenizer and model, ensuring to trust custom code from the model's repository
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", token="")
model = AutoModelForCausalLM.from_pretrained("apple/OpenELM-3B-Instruct", token="", trust_remote_code=True)

# Create the text generation pipeline
generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Define the prompt
prompt = "How to make spaghetti"

# Generate text with adjusted parameters
generated_text = generator(
    prompt,
    max_length=1024,
    truncation=True,
    do_sample=False,
    temperature=0.0,  # Adjusted for more natural variability
    top_p=0.95,
    top_k=40,
    repetition_penalty=1.2,  # Slightly reduced
    num_return_sequences=1
)

print(generated_text[0]['generated_text'])
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:509: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `40` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# ...
